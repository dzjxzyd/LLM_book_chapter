# %% [markdown]
# ### requirements for the following codings

# %%
### packages required
# !pip install fair-esm
# Out:
# Collecting fair-esm
#   Downloading fair_esm-2.0.0-py3-none-any.whl.metadata (37 kB)
# Downloading fair_esm-2.0.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: fair-esm
# Successfully installed fair-esm-2.0.0

# %%
import numpy as np
import pandas as pd
import esm
from keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv1D
from keras.layers import Dropout, AveragePooling1D, MaxPooling1D
from keras.models import Sequential,Model, load_model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
import keras
from keras import backend as K
import tensorflow as tf
if tf.test.gpu_device_name():
    print('GPU found')
    tf.config.experimental.set_visible_devices(tf.config.list_physical_devices('GPU')[0], 'GPU') # set the deep learning with GPU
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ### peptide embeddings with esm2_t6_8M_UR50D pretrained models
# 6 layers, 8M parameters, dataset: UR50/D 2021_04, embedding dimension: 320
# mode download URL: https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t6_8M_UR50D.pt
#
# original ESM github site is https://github.com/facebookresearch/esm

# %%
def esm_embeddings(esm2, esm2_alphabet, peptide_sequence_list):
  # NOTICE: ESM for embeddings is quite RAM usage, if your sequence is too long,
  #         or you have too many sequences for transformation in a single converting, (i personally suggest to do the embedding one by one if you are running locally or with T4 GPU at google colab)
  #         you computer might automatically kill the job.
  # load the python packages
  import torch
  import esm
  import collections
  import pandas as pd
  import gc
  # choose cuda for acceleration if available
  if torch.cuda.is_available():
    device = torch.device("cuda")
  else:
    device = torch.device("cpu")
  esm2.eval()
  esm2 = esm2.to(device)


  batch_converter = esm2_alphabet.get_batch_converter() # this function is to tokenize your peptide sequences from amino acid sequence into numbers

  # load the peptide sequence list into the bach_converter
  batch_labels, batch_strs, batch_tokens = batch_converter(peptide_sequence_list)
  batch_lens = (batch_tokens != alphabet.padding_idx).sum(1)
  ## batch tokens are the tokenized results of the whole data set
  batch_tokens = batch_tokens.to(device)
  # Extract per-residue representations (on CPU)
  with torch.no_grad():
      # Here we export the last layer of the EMS model output as the representation of the peptides
      # model'esm2_t6_8M_UR50D' only has 6 layers, and therefore repr_layers parameters is equal to 6
      # if you want to change the esm model, for example: esm2_t12_35M_UR50D, which has 12 layers, they you will need to change the 6 to 12 at the following two line
      results = esm2(batch_tokens, repr_layers=[6], return_contacts=False)
  token_representations = results["representations"][6].cpu() # the representation is generated for each amino acid residue; for example, if you have 3 residues, then the ourput shape is 3 * 320, 3 is the number of residues and the 320 is the vector for a single rediue

  # Generate per-sequence representations via averaging
  # NOTE: token 0 is always a beginning-of-sequence token, so we will discard it and start from token 1
  sequence_representations = []
  for i, tokens_len in enumerate(batch_lens):
      sequence_representations.append(token_representations[i, 1 : tokens_len - 1].mean(0))
  # save dataset
  # sequence_representations is a list and each element is a tensor
  embeddings_results = collections.defaultdict(list)
  for i in range(len(sequence_representations)):
      # tensor format can be transformed as numpy format sequence_representations[0].numpy() or sequence_representations[0].to_list
      each_seq_rep = sequence_representations[i].tolist()
      for each_element in each_seq_rep:
          embeddings_results[i].append(each_element)
  embeddings_results = pd.DataFrame(embeddings_results).T
  del  batch_labels, batch_strs, batch_tokens, results, token_representations # delete those variables to save GPU memory
  gc.collect() # release the GPU memory
  return embeddings_results

# %% [markdown]
# ### data loading and embeddings
# assume you have already split your dataset as a train and a test dataset.

# %% [markdown]
# #### Choose the ESM model and embeddings

# %%
# select the ESM model for embeddings (you can select you desired model from https://github.com/facebookresearch/esm)
# NOTICE: if you choose other model, the following model architecture might not be very compitable
#         bseides,please revise the correspdoning parameters in esm_embeddings function (layers for feature extraction)
model, alphabet = esm.pretrained.esm2_t6_8M_UR50D()

# %%
# training dataset loading
dataset = pd.read_excel('bitter_train.xlsx',header=0, index_col = None)
# generate embedding for seqeunces
sequence_list = dataset['sequence']
embeddings_results = pd.DataFrame()
for seq in sequence_list:
    # the setting is just following the input format setting in ESM model, [name,sequence]
    tuple_sequence = tuple([seq,seq])
    peptide_sequence_list = []
    peptide_sequence_list.append(tuple_sequence) # build a summarize list variable including all the sequence information
    # employ ESM model for converting and save the converted data in csv format
    one_seq_embeddings = esm_embeddings(model, alphabet, peptide_sequence_list)
    embeddings_results= pd.concat([embeddings_results,one_seq_embeddings])
embeddings_results.to_csv('train_main_esm2_t6_8M_UR50D_unified_320_dimension.csv')

# test dataset loading
dataset = pd.read_excel('bitter_test.xlsx',header=0, index_col = None)
# generate embedding for seqeunces
sequence_list = dataset['sequence']
embeddings_results = pd.DataFrame()
# embedding all the peptide one by one
for seq in sequence_list:
    # the setting is just following the input format setting in ESM model, [name,sequence]
    tuple_sequence = tuple([seq,seq] )
    peptide_sequence_list = []
    peptide_sequence_list.append(tuple_sequence) # build a summarize list variable including all the sequence information
    # employ ESM model for converting and save the converted data in csv format
    one_seq_embeddings = esm_embeddings(model, alphabet, peptide_sequence_list)
    embeddings_results= pd.concat([embeddings_results,one_seq_embeddings])
embeddings_results.to_csv('test_main_esm2_t6_8M_UR50D_unified_320_dimension.csv')

# %% [markdown]
# #### dataset division
# ready for training and evaluation

# %%
# training dataset loading
dataset = pd.read_excel('bitter_train.xlsx',na_filter = False) # take care the NA sequence problem
sequence_list = dataset['sequence']
y_train = dataset['label']
y_train = np.array(y_train) # transformed as np.array for CNN model

# test dataset loading
dataset = pd.read_excel('bitter_test.xlsx',na_filter = False) # take care the NA sequence problem
sequence_list = dataset['sequence']
y_test = dataset['label']
y_test = np.array(y_test) # transformed as np.array for CNN model

# loading the peptide embddings
X_train = pd.read_csv('train_main_esm2_t6_8M_UR50D_unified_320_dimension.csv',header=0, index_col = 0,delimiter=',')
X_test = pd.read_csv('test_main_esm2_t6_8M_UR50D_unified_320_dimension.csv',header=0, index_col = 0,delimiter=',')
# generate the validation dataset for early stopping
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=123, shuffle= True, stratify =y_train )

# transform the dataset into numpy format
X_train = np.array(X_train)
X_valid = np.array(X_valid)
X_test = np.array(X_test)

# normalize the X data range
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train) # normalize X to 0-1 range
X_valid = scaler.transform(X_valid) # normalize X to 0-1 range
X_test = scaler.transform(X_test)

# %%
# check the dimension of the dataset before model development
print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)

print(y_train.shape)
print(y_valid.shape)
print(y_test.shape)
# Out:
# (409, 320)
# (103, 320)
# (128, 320)
# (409,)
# (103,)
# (128,)

# %% [markdown]
# ### dataset loading and embeddings
# (if you only have one dataset and need to split them)

# %% [markdown]
# #### Choose the ESM model and embeddings

# %%
# select the ESM model for embeddings (you can select you desired model from https://github.com/facebookresearch/esm)
# NOTICE: if you choose other model, the following model architecture might not be very compitable
#         bseides,please revise the correspdoning parameters in esm_embeddings function (layers for feature extraction)
model, alphabet = esm.pretrained.esm2_t6_8M_UR50D()
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t6_8M_UR50D.pt" to /root/.cache/torch/hub/checkpoints/esm2_t6_8M_UR50D.pt
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/regression/esm2_t6_8M_UR50D-contact-regression.pt" to /root/.cache/torch/hub/checkpoints/esm2_t6_8M_UR50D-contact-regression.pt

# %%
# whole dataset loading and dataset splitting
dataset = pd.read_excel('bitter_single_dataset_example.xlsx',header=0, index_col = None)

# generate the peptide embeddings
sequence_list = dataset['sequence']
embeddings_results = pd.DataFrame()
for seq in sequence_list:
    # the setting is just following the input format setting in ESM model, [name,sequence]
    tuple_sequence = tuple([seq,seq])
    peptide_sequence_list = []
    peptide_sequence_list.append(tuple_sequence) # build a summarize list variable including all the sequence information
    # employ ESM model for converting and save the converted data in csv format
    one_seq_embeddings = esm_embeddings(model, alphabet, peptide_sequence_list)
    embeddings_results= pd.concat([embeddings_results,one_seq_embeddings])
embeddings_results.to_csv('whole_sample_dataset_esm2_t6_8M_UR50D_unified_320_dimension.csv')

# %% [markdown]
# #### dataset division
# ready for training and evaluation

# %%
# loading the y dataset for model development
y = dataset['label']
y = np.array(y) # transformed as np.array for CNN model

# read the peptide embeddings
X_data = pd.read_csv('whole_sample_dataset_esm2_t6_8M_UR50D_unified_320_dimension.csv',header=0, index_col = 0,delimiter=',')
X = np.array(X_data)

# split dataset as training and test dataset as ratio of 8:2
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=123, shuffle= True, stratify =y)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=234, shuffle= True, stratify =y_train)


# normalize the X data range
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train) # normalize X to 0-1 range
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
# check the dimension of the dataset before model development
print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)

print(y_train.shape)
print(y_valid.shape)
print(y_test.shape)
# Out:
# (409, 320)
# (103, 320)
# (128, 320)
# (409,)
# (103,)
# (128,)

# %% [markdown]
# ### Model architecture

# %%
def ESM_CNN(X_train, y_train, X_test, y_test):
  inputShape=(320,1) # input feature size
  input = Input(inputShape)
  x = Conv1D(32,(3),strides = (1),name='layer_conv1',padding='same')(input)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = MaxPooling1D((2), name='MaxPool1',padding="same")(x)
  x = Dropout(0.15)(x)
  x = Flatten()(x)
  x = Dense(64,activation = 'relu',name='fc1')(x)
  x = Dropout(0.15)(x)
  x = Dense(2,activation = 'softmax',name='fc2')(x)
  model = Model(inputs = input,outputs = x,name='Predict')
  adam = Adam(learning_rate=0.001)
  # compile the model
  model.compile(loss='sparse_categorical_crossentropy',optimizer=adam, metrics=['accuracy'])
  # set checkpoint and save the best model
  mc = ModelCheckpoint('best_model.keras',  monitor='val_accuracy', mode='max', verbose=1, save_best_only=True, save_weights_only=False)
  # summary the callbacks_list
  callbacks_list = [mc]
  model_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=200,callbacks=callbacks_list,batch_size = 8, verbose=1)
  return model, model_history

# %% [markdown]
# ### model training and evaluation at test dataset

# %%
# train the model & best model checkpoint will be save as 'best_model.keras'
model, model_history = ESM_CNN(X_train, y_train, X_valid, y_valid)
# Out:
# Epoch
val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9939 - loss: 0.0110 - val_accuracy: 0.9126 - val_loss: 0.7285
# Epoch 139/200
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0172
# Epoch 139: val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9930 - loss: 0.0170 - val_accuracy: 0.9223 - val_loss: 0.7376
# Epoch 140/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9891 - loss: 0.0229
# Epoch 140: val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0221 - val_accuracy: 0.9126 - val_loss: 0.6548
# Epoch 141/200
# 37/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 141: val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9994 - loss: 0.0080 - val_accuracy: 0.9029 - val_loss: 0.6714
# Epoch 142/200
# 39/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9869 - loss: 0.0271
# Epoch 142: val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9848 - loss: 0.0303 - val_accuracy: 0.9029 - val_loss: 0.7109
# Epoch 143/200
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9844 - loss: 0.0314
# Epoch 143: val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9839 - loss: 0.0325 - val_accuracy: 0.8544 - val_loss: 0.7907
# Epoch 144/200
# 43/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9717 - loss: 0.0702
# Epoch 144: val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9730 - loss: 0.0655 - val_accuracy: 0.9029 - val_loss: 0.5444
# Epoch 145/200
# 42/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9798 - loss: 0.0332
# Epoch 145: val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9796 - loss: 0.0342 - val_accuracy: 0.8932 - val_loss: 0.6994
# Epoch 146/200
# 42/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 0.0633
# Epoch 146: val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9697 - loss: 0.0588 - val_accuracy: 0.8738 - val_loss: 0.5880
# Epoch 147/200
# 36/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9792 - loss: 0.0344
# Epoch 147: val_accuracy did not improve from 0.92233
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9796 - loss: 0.0359 - val_accuracy: 0.9223 - val_loss: 0.6173
# Epoch 148/200
# 39/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9816 - loss: 0.0274
# Epoch 148: val_accuracy improved from 0.92233 to 0.93204, saving model to best_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9807 - loss: 0.0290 - val_accuracy: 0.9320 - val_loss: 0.6610
# Epoch 149/200
# 36/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9872 - loss: 0.0351
# Epoch 149: val_accuracy did not improve from 0.93204
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0297 - val_accuracy: 0.9223 - val_loss: 0.6683
# Epoch 150/200
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9909 - loss: 0.0111
# Epoch 150: val_accuracy did not improve from 0.93204
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9907 - loss: 0.0114 - val_accuracy: 0.9320 - val_loss: 0.5738
# Epoch 151/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0065
# Epoch 151: val_accuracy improved from 0.93204 to 0.94175, saving model to best_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9943 - loss: 0.0096 - val_accuracy: 0.9417 - val_loss: 0.5968
# Epoch 152/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9529 - loss: 0.0443
# Epoch 152: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9647 - loss: 0.0361 - val_accuracy: 0.9223 - val_loss: 0.7128
# Epoch 153/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9891 - loss: 0.0214
# Epoch 153: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9888 - loss: 0.0226 - val_accuracy: 0.9223 - val_loss: 0.6777
# Epoch 154/200
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0131
# Epoch 154: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9927 - loss: 0.0132 - val_accuracy: 0.9126 - val_loss: 0.7399
# Epoch 155/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0058
# Epoch 155: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9948 - loss: 0.0090 - val_accuracy: 0.9320 - val_loss: 0.7026
# Epoch 156/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9728 - loss: 0.0390
# Epoch 156: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9785 - loss: 0.0305 - val_accuracy: 0.9126 - val_loss: 0.8736
# Epoch 157/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0092
# Epoch 157: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0090 - val_accuracy: 0.9126 - val_loss: 0.8092
# Epoch 158/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 158: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9029 - val_loss: 0.8943
# Epoch 159/200
# 28/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9961 - loss: 0.0102
# Epoch 159: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9940 - loss: 0.0149 - val_accuracy: 0.9320 - val_loss: 0.8056
# Epoch 160/200
# 28/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.0198
# Epoch 160: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9900 - loss: 0.0192 - val_accuracy: 0.9223 - val_loss: 1.0564
# Epoch 161/200
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9859 - loss: 0.0272
# Epoch 161: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9858 - loss: 0.0271 - val_accuracy: 0.9223 - val_loss: 0.7975
# Epoch 162/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9817 - loss: 0.0194
# Epoch 162: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9852 - loss: 0.0179 - val_accuracy: 0.9223 - val_loss: 0.7222
# Epoch 163/200
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9877 - loss: 0.0303
# Epoch 163: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9875 - loss: 0.0303 - val_accuracy: 0.9223 - val_loss: 0.7858
# Epoch 164/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0064
# Epoch 164: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0083 - val_accuracy: 0.9029 - val_loss: 0.7738
# Epoch 165/200
# 25/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9884 - loss: 0.0175
# Epoch 165: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9873 - loss: 0.0209 - val_accuracy: 0.8738 - val_loss: 1.0623
# Epoch 166/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9762 - loss: 0.0339
# Epoch 166: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9772 - loss: 0.0308 - val_accuracy: 0.9223 - val_loss: 0.8471
# Epoch 167/200
# 28/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0187
# Epoch 167: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9915 - loss: 0.0227 - val_accuracy: 0.9223 - val_loss: 0.7457
# Epoch 168/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.0699
# Epoch 168: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9732 - loss: 0.0657 - val_accuracy: 0.8835 - val_loss: 0.6842
# Epoch 169/200
# 25/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9947 - loss: 0.0345
# Epoch 169: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9926 - loss: 0.0338 - val_accuracy: 0.8835 - val_loss: 0.8340
# Epoch 170/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9907 - loss: 0.0339
# Epoch 170: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9915 - loss: 0.0286 - val_accuracy: 0.8641 - val_loss: 1.4346
# Epoch 171/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.0316
# Epoch 171: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9907 - loss: 0.0336 - val_accuracy: 0.8932 - val_loss: 0.7955
# Epoch 172/200
# 27/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9873 - loss: 0.0310
# Epoch 172: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9886 - loss: 0.0265 - val_accuracy: 0.8932 - val_loss: 0.7819
# Epoch 173/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0118
# Epoch 173: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0142 - val_accuracy: 0.9029 - val_loss: 0.8163
# Epoch 174/200
# 27/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0110
# Epoch 174: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9948 - loss: 0.0146 - val_accuracy: 0.9126 - val_loss: 0.9036
# Epoch 175/200
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9959 - loss: 0.0148
# Epoch 175: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9956 - loss: 0.0154 - val_accuracy: 0.8835 - val_loss: 0.8216
# Epoch 176/200
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0069
# Epoch 176: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9983 - loss: 0.0071 - val_accuracy: 0.8932 - val_loss: 0.7532
# Epoch 177/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9834 - loss: 0.0265
# Epoch 177: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9874 - loss: 0.0213 - val_accuracy: 0.9029 - val_loss: 0.8488
# Epoch 178/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0051
# Epoch 178: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9963 - loss: 0.0081 - val_accuracy: 0.9029 - val_loss: 0.7833
# Epoch 179/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0096
# Epoch 179: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9956 - loss: 0.0144 - val_accuracy: 0.8835 - val_loss: 0.9487
# Epoch 180/200
# 31/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9636 - loss: 0.0477
# Epoch 180: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9686 - loss: 0.0433 - val_accuracy: 0.9320 - val_loss: 0.6219
# Epoch 181/200
# 48/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9878 - loss: 0.0202
# Epoch 181: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.0199 - val_accuracy: 0.9126 - val_loss: 0.8200
# Epoch 182/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0073
# Epoch 182: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9959 - loss: 0.0086 - val_accuracy: 0.9029 - val_loss: 0.9726
# Epoch 183/200
# 27/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.0194
# Epoch 183: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9877 - loss: 0.0235 - val_accuracy: 0.9126 - val_loss: 0.8912
# Epoch 184/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.0286
# Epoch 184: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.0302 - val_accuracy: 0.9126 - val_loss: 0.7347
# Epoch 185/200
# 28/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.0252
# Epoch 185: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9885 - loss: 0.0250 - val_accuracy: 0.9320 - val_loss: 0.7723
# Epoch 186/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0125
# Epoch 186: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9960 - loss: 0.0125 - val_accuracy: 0.8835 - val_loss: 0.8762
# Epoch 187/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.0258
# Epoch 187: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0338 - val_accuracy: 0.9223 - val_loss: 0.7652
# Epoch 188/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9952 - loss: 0.0208
# Epoch 188: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0264 - val_accuracy: 0.8835 - val_loss: 0.6736
# Epoch 189/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 189: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.8932 - val_loss: 0.7652
# Epoch 190/200
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9894 - loss: 0.0152
# Epoch 190: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9897 - loss: 0.0151 - val_accuracy: 0.9029 - val_loss: 0.9184
# Epoch 191/200
# 29/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.0051
# Epoch 191: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9907 - loss: 0.0117 - val_accuracy: 0.8932 - val_loss: 0.7776
# Epoch 192/200
# 30/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0286
# Epoch 192: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0258 - val_accuracy: 0.8932 - val_loss: 0.8847
# Epoch 193/200
# 41/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9804 - loss: 0.0341
# Epoch 193: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9818 - loss: 0.0332 - val_accuracy: 0.9126 - val_loss: 0.6238
# Epoch 194/200
# 39/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9969 - loss: 0.0085
# Epoch 194: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9958 - loss: 0.0094 - val_accuracy: 0.8835 - val_loss: 0.9543
# Epoch 195/200
# 40/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9889 - loss: 0.0173
# Epoch 195: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0169 - val_accuracy: 0.8932 - val_loss: 0.8334
# Epoch 196/200
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9810 - loss: 0.0546
# Epoch 196: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9814 - loss: 0.0530 - val_accuracy: 0.8835 - val_loss: 0.7312
# Epoch 197/200
# 34/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 197: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0118 - val_accuracy: 0.8835 - val_loss: 0.7611
# Epoch 198/200
# 48/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9865 - loss: 0.0210
# Epoch 198: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9857 - loss: 0.0221 - val_accuracy: 0.9029 - val_loss: 0.6317
# Epoch 199/200
# 40/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9809 - loss: 0.0303
# Epoch 199: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9806 - loss: 0.0306 - val_accuracy: 0.8835 - val_loss: 0.7192
# Epoch 200/200
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9973 - loss: 0.0080
# Epoch 200: val_accuracy did not improve from 0.94175
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9969 - loss: 0.0084 - val_accuracy: 0.8932 - val_loss: 0.7320

# %%
# load the saved best model for performance evaluation at test dataset
saved_model = load_model('best_model.keras')
# result collection list
ACC_collecton = []
BACC_collecton = []
Sn_collecton = []
Sp_collecton = []
recall_collecton = []
precision_collecton = []
f1_collecton = []
MCC_collecton = []
AUC_collecton = []
# confusion matrix
predicted_class= []
predicted_protability = saved_model.predict(X_test,batch_size=1)
for i in range(predicted_protability.shape[0]):
  index = np.where(predicted_protability[i] == np.amax(predicted_protability[i]))[0][0] # the class with higher protability was treated as the prediction class
  predicted_class.append(index)

predicted_class = np.array(predicted_class) # transformed into a numpy for performance evaluation
y_true = y_test
from sklearn.metrics import confusion_matrix
import math
# np.ravel() return a flatten 1D array
TN, FP, FN, TP = confusion_matrix(y_true, predicted_class).ravel() # shape [ [True-Positive, False-positive], [False-negative, True-negative] ]
ACC = (TP+TN)/(TP+TN+FP+FN)
ACC_collecton.append(ACC)
Sn_collecton.append(TP/(TP+FN))
Sp_collecton.append(TN/(TN+FP))
recall_collecton.append(TP/(TP+FN))
precision_collecton.append(TP/(TP+FP))
f1_collecton.append(2*TP/(TP+FP)*TP/(TP+FN)/ (TP/(TP+FP)+TP/(TP+FN)))
MCC = (TP*TN-FP*FN)/math.pow(((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN)),0.5)
MCC_collecton.append(MCC)
BACC_collecton.append(0.5*TP/(TP+FN)+0.5*TN/(TN+FP))
# print the performance in the test dataset
from sklearn.metrics import roc_auc_score
AUC = roc_auc_score(y_test, predicted_protability[:,1])
AUC_collecton.append(AUC)
print(ACC_collecton[0])
print(BACC_collecton[0])
print(Sn_collecton[0])
print(Sp_collecton[0])
print(recall_collecton[0])
print(precision_collecton[0])
print(f1_collecton[0])
print(MCC_collecton[0])
print(AUC_collecton[0])
# Out:
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 0.84375
# 0.84375
# 0.828125
# 0.859375
# 0.828125
# 0.8548387096774194
# 0.8412698412698412
# 0.6878359394287946
# 0.9212646484375

# %% [markdown]
# ### model usage at new dataset

# %% [markdown]
# #### generate embeddings for new dataset

# %%
model, alphabet = esm.pretrained.esm2_t6_8M_UR50D()
# new dataset loading
dataset = pd.read_excel('bitter_new_data.xlsx',header=0, index_col = None)
# generate embedding for seqeunces
sequence_list = dataset['sequence']
embeddings_results = pd.DataFrame()
for seq in sequence_list:
    # the setting is just following the input format setting in ESM model, [name,sequence]
    tuple_sequence = tuple([seq,seq])
    peptide_sequence_list = []
    peptide_sequence_list.append(tuple_sequence) # build a summarize list variable including all the sequence information
    # employ ESM model for converting and save the converted data in csv format
    one_seq_embeddings = esm_embeddings(model, alphabet, peptide_sequence_list)
    embeddings_results= pd.concat([embeddings_results,one_seq_embeddings])
embeddings_results.to_csv('new_data_esm2_t6_8M_UR50D_unified_320_dimension.csv')

# %% [markdown]
# #### loading scaler (optional)
# you only need to run this section if you choose to use scaler
#
# assume you have already split your dataset as a train and a test dataset in the above methods

# %%
# loading scaler from new dataset
X_train = pd.read_csv('train_main_esm2_t6_8M_UR50D_unified_320_dimension.csv',header=0, index_col = 0,delimiter=',')
# transform the dataset into numpy format
X_train = np.array(X_train)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
# loading the peptide embddings
X_new_embeddings = pd.read_csv('new_data_esm2_t6_8M_UR50D_unified_320_dimension.csv',header=0, index_col = 0,delimiter=',')
# transform the dataset into numpy format
X_new = np.array(X_new_embeddings)
X_new = scaler.transform(X_new) # normalize X to 0-1 range

# %% [markdown]
# #### loading scaler (optional)
# you only need to run this section if you choose to use scaler
#
# if you only use one dataset above, run this cell instead of the above section for two datasets

# %%
# read the peptide embeddings
X_data = pd.read_csv('whole_sample_dataset_esm2_t6_8M_UR50D_unified_320_dimension.csv',header=0, index_col = 0,delimiter=',')
X = np.array(X_data)

# please make sure the following numbers for random_state is consistant with the above data division section.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=123, shuffle= True, stratify =y)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=234, shuffle= True, stratify =y_train)
# loading the peptide embddings
X_new_embeddings = pd.read_csv('new_data_esm2_t6_8M_UR50D_unified_320_dimension.csv',header=0, index_col = 0,delimiter=',')
# normalize the X data range
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_new = np.array(X_new_embeddings)
X_new = scaler.transform(X_new) # normalize X to 0-1 range

# %% [markdown]
# #### predict the dataset

# %%
# load the saved best model for performance evaluation at test dataset
saved_model = load_model('best_model.keras')
# confusion matrix
predicted_class= []
predicted_protability = saved_model.predict(X_new,batch_size=1)
for i in range(predicted_protability.shape[0]):
  index = np.where(predicted_protability[i] == np.amax(predicted_protability[i]))[0][0]
  predicted_class.append(index)
predicted_class = np.array(predicted_class)
for i in range(dataset.shape[0]):
  dataset.iloc[i,1] = predicted_class[i]
dataset.to_excel('new_data_prediction_result.xlsx')
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
